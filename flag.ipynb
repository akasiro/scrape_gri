# %%
from urllib.parse import urljoin
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

# %%
data_dict = {'flag_url':[],'country':[]}
tmp = pd.read_csv('flag_tmp.csv')
domain_url = 'https://database.globalreporting.org/'
for r in tmp.itertuples():
    tmp_dict = {}
    src = getattr(r,'country')
    src = src.replace('16','24')
    tmp_dict['flag_url'] = src
    url = getattr(r,'ORG_url')
    url = urljoin(domain_url,url)
    res = requests.get(url,verify=False)
    soup = BeautifulSoup(res.content,'html.parser')
    country = soup.find('img',{'src':src}).next_sibling.next_sibling.get_text()
    tmp_dict['country'] = country
    for k in data_dict.keys():
        data_dict[k].append(tmp_dict.get(k))
    time.sleep(60)
# Out:
# /home/ping/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'database.globalreporting.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/ping/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'database.globalreporting.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/ping/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'database.globalreporting.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# ...

# %%
data_dict
# Out:
# {'flag_url': ['/static/img/flag-icons/flags_iso/24/tw.png',
#   '/static/img/flag-icons/flags_iso/24/de.png',
#   '/static/img/flag-icons/flags_iso/24/af.png',
#   '/static/img/flag-icons/flags_iso/24/za.png',
#   '/static/img/flag-icons/flags_iso/24/ch.png',
#   '/static/img/flag-icons/flags_iso/24/us.png',
#   '/static/img/flag-icons/flags_iso/24/ph.png',
#   '/static/img/flag-icons/flags_iso/24/cn.png',
#   '/static/img/flag-icons/flags_iso/24/pe.png',
#   '/static/img/flag-icons/flags_iso/24/.png',
#   '/static/img/flag-icons/flags_iso/24/ar.png',
#   '/static/img/flag-icons/flags_iso/24/br.png',
#   '/static/img/flag-icons/flags_iso/24/hk.png',
#   '/static/img/flag-icons/flags_iso/24/hu.png',
#   '/static/img/flag-icons/flags_iso/24/vn.png',
#   '/static/img/flag-icons/flags_iso/24/tr.png',
#   '/static/img/flag-icons/flags_iso/24/es.png',
#   '/static/img/flag-icons/flags_iso/24/jp.png',
#   '/static/img/flag-icons/flags_iso/24/il.png',
# ...

# %%
df = pd.DataFrame(data_dict)

# %%
df.head()
# Out:
#                                      flag_url       country
# 0  /static/img/flag-icons/flags_iso/24/tw.png        Taiwan
# 1  /static/img/flag-icons/flags_iso/24/de.png       Germany
# 2  /static/img/flag-icons/flags_iso/24/af.png   Afghanistan
# 3  /static/img/flag-icons/flags_iso/24/za.png  South Africa
# 4  /static/img/flag-icons/flags_iso/24/ch.png   Switzerland

# %%
def modify_flag_url(value):
    value = value.replace('24','16')
    return value

# %%
df['flag_url'] = df['flag_url'].apply(modify_flag_url)

# %%
print(df.shape)
df.head()
# Out:
# (143, 2)
#                                      flag_url       country
# 0  /static/img/flag-icons/flags_iso/16/tw.png        Taiwan
# 1  /static/img/flag-icons/flags_iso/16/de.png       Germany
# 2  /static/img/flag-icons/flags_iso/16/af.png   Afghanistan
# 3  /static/img/flag-icons/flags_iso/16/za.png  South Africa
# 4  /static/img/flag-icons/flags_iso/16/ch.png   Switzerland

# %%
df.to_excel('flag_country.xlsx',index=False)
